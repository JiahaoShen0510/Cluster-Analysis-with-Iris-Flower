# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.cluster import KMeans
from sklearn import preprocessing

# %%
# import and organize the dataset

# %%
data0=pd.read_csv("iris_dataset.csv")
data0
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
data0.isnull().count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# dtype: int64

# %%
# cluster analysis without standardization

# %%
x=data0[["sepal_length","sepal_width","petal_length","petal_width"]]

# %%
kmeans=KMeans()

# %%
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
wcss=[]

for i in range (1,151):
    kmeans=KMeans(i)
    kmeans.fit(x)
    wcss_inet=kmeans.inertia_
    wcss.append(wcss_inet)

# %%
wcss
# Out:
# [680.8244,
#  152.36870647733906,
#  78.94084142614602,
#  57.31787321428571,
#  46.53558205128205,
#  38.930963049671746,
#  34.18920546865627,
#  29.881402210510913,
#  27.99393421052632,
#  26.388146542827663,
#  24.178631799572976,
#  23.012314102564105,
#  21.265031057178117,
#  20.242928030303034,
#  18.996237345987346,
#  18.592091880341883,
#  16.809154761904765,
#  16.30097313797314,
#  15.808534632034636,
#  14.697398629148633,
#  14.348519841269843,
#  13.363385753135756,
#  12.962786935286937,
#  12.785558441558443,
#  12.05287520159579,
#  11.650847485847489,
#  11.176190476190477,
#  11.032934523809525,
#  10.565126984126984,
#  10.215535714285714,
#  9.892476190476192,
#  9.589916666666669,
#  9.374936896436898,
#  8.950603535353537,
#  8.617190476190476,
#  8.500916666666667,
#  8.115130952380953,
#  7.848289682539683,
#  7.797765873015874,
#  7.42675,
#  7.056871212121212,
#  6.970444444444445,
#  6.763404761904763,
#  6.334250000000001,
#  6.32838888888889,
# ...

# %%
number_clusters=range (1,151)
plt.plot(number_clusters,wcss)
plt.xlabel("Clusters",fontsize=15)
plt.ylabel("Sum of Squares of the Distances",fontsize=15)
plt.xlim(0,10)
# Out:
# (0, 10)

# %%
kmeans01=KMeans(2)

# %%
kmeans01.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(data0["sepal_length"],data0["sepal_width"],c=kmeans01.fit_predict(x),cmap="rainbow")
plt.xlabel("Sepal Length:2 clusters",fontsize=15)
plt.ylabel("Sepal Width: 2clusters",fontsize=15)
# Out:
# Text(0, 0.5, 'Sepal Width: 2clusters')

# %%
plt.scatter(data0["petal_length"],data0["petal_width"],c=kmeans01.fit_predict(x),cmap="rainbow")
plt.xlabel("Petal Length:2 clusters",fontsize=15)
plt.ylabel("Petal Width:2 clusters",fontsize=15)
# Out:
# Text(0, 0.5, 'Petal Width:2 clusters')

# %%
kmeans02=KMeans(3)

# %%
kmeans02.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(data0["sepal_length"],data0["sepal_width"],c=kmeans02.fit_predict(x),cmap="rainbow")
plt.xlabel("Sepal Length:3 clusters",fontsize=15)
plt.ylabel("Sepal Width: 3 clusters",fontsize=15)
# Out:
# Text(0, 0.5, 'Sepal Width: 3 clusters')

# %%
plt.scatter(data0["petal_length"],data0["petal_width"],c=kmeans02.fit_predict(x),cmap="rainbow")
plt.xlabel("Petal Length:3 clusters",fontsize=15)
plt.ylabel("Petal Width: 3 clusters",fontsize=15)
# Out:
# Text(0, 0.5, 'Petal Width: 3 clusters')

# %%
# cluster analysis with the standardized data

# %%
x_scaled=preprocessing.scale(x)

# %%
kmeans_scaled=KMeans()

# %%
kmeans_scaled.fit(x_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
wcss_scaled=[]

for i in range (1,151):
    kmeans_scaled=KMeans(i)
    kmeans_scaled.fit(x_scaled)
    wcss_inet_scaled=kmeans_scaled.inertia_
    wcss_scaled.append(wcss_inet_scaled)

# %%
wcss_scaled
# Out:
# [600.0,
#  223.73200573676345,
#  140.96581663074699,
#  114.57683895971645,
#  91.00244098567248,
#  80.20433441381101,
#  71.95048250102842,
#  62.6196948572166,
#  55.38272853338333,
#  47.3303248968365,
#  43.05009214904571,
#  41.049201194416845,
#  36.52920519699788,
#  35.38543289705767,
#  33.16243425152989,
#  31.135983739039602,
#  29.02003039475402,
#  26.812518135644982,
#  25.83471557603606,
#  24.155943258969998,
#  23.57769162596194,
#  22.677591549922354,
#  21.56251561384884,
#  20.161766271421147,
#  18.82200623001853,
#  18.724065947966302,
#  17.94153008379557,
#  17.433834791118947,
#  16.108392162038804,
#  16.01027373715872,
#  15.14033826187339,
#  14.729002283892154,
#  14.51286449883371,
#  13.500391916609598,
#  13.408593180377244,
#  12.68660372116315,
#  12.31006441935688,
#  11.75840253032316,
#  11.716778167279983,
#  11.239057709766774,
#  10.770626971199803,
#  10.576357099031775,
#  9.83677147098775,
#  9.948374371804555,
#  9.394094042841417,
# ...

# %%
plt.plot(number_clusters, wcss_scaled)
plt.xlabel("Clusters",fontsize=15)
plt.ylabel("Sum of Squares of the Distances",fontsize=15)
plt.xlim(0,20)
# Out:
# (0, 20)

# %%
kmeans_scaled01=KMeans(2)

# %%
kmeans_scaled01.fit(x_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(data0["sepal_length"],data0["sepal_width"],c=kmeans_scaled01.fit_predict(x_scaled),cmap="rainbow")
plt.xlabel("Sepal Length:2 clusters",fontsize=15)
plt.ylabel("Sepal Width:2 clusters",fontsize=15)
# Out:
# Text(0, 0.5, 'Sepal Width:2 clusters')

# %%
plt.scatter(data0["petal_length"],data0["petal_width"],c=kmeans_scaled01.fit_predict(x_scaled),cmap="rainbow")
plt.xlabel("Petal Length:2 clusters",fontsize=15)
plt.ylabel("Petal Width:2 clusters",fontsize=15)
# Out:
# Text(0, 0.5, 'Petal Width:2 clusters')

# %%
kmeans_scaled02=KMeans(3)

# %%
kmeans_scaled02.fit(x_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(data0["sepal_length"],data0["sepal_width"],c=kmeans_scaled02.fit_predict(x_scaled),cmap="rainbow")
plt.xlabel("Sepal Length:3 clusters",fontsize=15)
plt.ylabel("Sepal Width:3 clusters",fontsize=15)
# Out:
# Text(0, 0.5, 'Sepal Width:3 clusters')

# %%
plt.scatter(data0["petal_length"],data0["petal_width"],c=kmeans_scaled02.fit_predict(x_scaled),cmap="rainbow")
plt.xlabel("Petal Length:3 clusters",fontsize=15)
plt.ylabel("Petal Width:3 clusters",fontsize=15)
# Out:
# Text(0, 0.5, 'Petal Width:3 clusters')
